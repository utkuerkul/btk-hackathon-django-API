# %%
import os
import time
import google.generativeai as genai

# %%
import pandas as pd 

yks_df = pd.read_excel("yks_excel.xlsx")

# %%
yks_df
# Out:
#        Program Kodu Üniversites Türü                        Üniversite Adı  \
# 0         106510090           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 1         106510089           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 2         106510014           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 3         106510077           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 4         106510068           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# ...             ...              ...                                   ...
# 21860     110390159           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21861     110350761           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21862     110351177           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21863     110371093           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21864     110350337           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
#
#                     Fakülte/Yüksekokul Adı  \
# ...

# %%
yks_df = yks_df[yks_df["Program Adı"].str.contains("Psikoloji", case=False, na=False)]

# %%
yks_df
# Out:
#        Program Kodu Üniversites Türü  \
# 0         106510090           DEVLET
# 15        200190040            VAKIF
# 16        200110123            VAKIF
# 17        200190052            VAKIF
# 18        200190051            VAKIF
# ...             ...              ...
# 11686     110110313           DEVLET
# 11746     102310294           DEVLET
# 11814     110310559           DEVLET
# 11839     110310638           DEVLET
# 11840     110330281           DEVLET
#
#                                           Üniversite Adı  \
# 0                    ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 15     ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 16     ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 17     ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 18     ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# ...                                                  ...
# 11686              YILDIZ TEKNİK ÜNİVERSİTESİ (İSTANBUL)
# ...

# %%
yks_ex = pd.read_excel(r"C:\Users\utku-\Desktop\KAGGLE\BTK Hackaton Django\yks_excel_extended.xlsx")

# %%
merged_df = pd.merge(yks_df, yks_ex, on='Program Kodu', how='inner')

# %%
merged_df
# Out:
#      Program Kodu Üniversites Türü  \
# 0       106510090           DEVLET
# 1       200190040            VAKIF
# 2       200110123            VAKIF
# 3       200190052            VAKIF
# 4       200190051            VAKIF
# ..            ...              ...
# 485     110110313           DEVLET
# 486     102310294           DEVLET
# 487     110310559           DEVLET
# 488     110310638           DEVLET
# 489     110330281           DEVLET
#
#                                         Üniversite Adı  \
# 0                  ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 1    ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 2    ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 3    ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 4    ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# ..                                                 ...
# 485              YILDIZ TEKNİK ÜNİVERSİTESİ (İSTANBUL)
# 486                          YOZGAT BOZOK ÜNİVERSİTESİ
# ...

# %%
# Güncellenmiş DataFrame'i Excel dosyasına kaydetme
output_file = r"C:\Users\utku-\Desktop\KAGGLE\BTK Hackaton Django\hackhaton_btk\api\yks_excel_updated.xlsx"
merged_df.to_excel(output_file, index=False)

# %%
filtered = merged_df["Üniversite Adı"].str.contains("YILDIZ TEKNİK ÜNİVERSİTESİ", case=False, na=False)
print("Eşleşen satırlar (Üniversite Adı):")
print(merged_df[filtered])

filtered2 = merged_df["Program Adı"].str.contains("Rehberlik ve Psikolojik Danışmanlık", case=False, na=False)
print("Eşleşen satırlar (Program Adı):")
print(merged_df[filtered2])
# Out:
# Eşleşen satırlar (Üniversite Adı):
#      Program Kodu Üniversites Türü                         Üniversite Adı  \
# 485     110110313           DEVLET  YILDIZ TEKNİK ÜNİVERSİTESİ (İSTANBUL)
#
#     Fakülte/Yüksekokul Adı                          Program Adı Puan Türü  \
# 485       Eğitim Fakültesi  Rehberlik ve Psikolojik Danışmanlık        EA
#
#      Kontenjan  Yerleşen_x En Küçük Puan En Büyük Puan  ...  \
# 485         70          70     385.29609     444.17315  ...
#
#     AYT Coğrafya-1 (6 soruda) AYT Tarih-1 (10 soruda) AYT Fizik (14 soruda)  \
# 485                       3,7                     6,8                   NaN
#
#     AYT Kimya (13 soruda) AYT Biyoloji (13 soruda)  \
# 485                   NaN                      NaN
#
#     YDT Yabancı Dil (80 soruda) AYT Coğrafya-2 (11 soruda)  \
# 485                         NaN                        NaN
#
#     AYT Tarih-2 (11 soruda) AYT Felsefe Grubu (12 soruda)  \
# ...

# %%
import os
import pandas as pd
from huggingface_hub import InferenceClient
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
import logging
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader,ServiceContext,Document,PromptTemplate
from llama_index.core import Settings
import unicodedata

# Logger Ayarı
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Hugging Face API Ayarları
HUGGING_FACE_TOKEN = os.getenv("HUGGING_FACE_TOKEN", "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")
MODEL_NAME = os.getenv("MODEL_NAME", "meta-llama/Llama-3.3b")

# Inference API istemcisi
client = InferenceClient(token=HUGGING_FACE_TOKEN)

def call_inference_api(prompt):
    """
    Hugging Face Inference API ile modelden yanıt üretir.
    """
    try:
        response = client.text_generation(model=MODEL_NAME, inputs=prompt, max_new_tokens=500, temperature=0.7)
        return response["generated_text"]
    except Exception as e:
        logger.error(f"Model çalıştırılırken hata oluştu: {str(e)}")
        return f"Model çalıştırılırken hata oluştu: {str(e)}"
