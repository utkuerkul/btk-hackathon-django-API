# %%
import pandas as pd

# %%
yks= pd.read_excel(r"C:\Users\utku-\Desktop\KAGGLE\BTK Hackaton\tablo4yd_22082023.xlsx")

# %%
yks.columns = yks.iloc[1]

# %%
yks = yks.drop(index=[0,1])

# %%
yks
# Out:
# 1     Program Kodu Üniversites Türü                        Üniversite Adı  \
# 2        106510090           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 3        106510089           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 4        106510014           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 5        106510077           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 6        106510068           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# ...            ...              ...                                   ...
# 11860    110310656           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 11861    110310665           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 11862    110390169           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 11863    110310144           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 11864    110390172           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
#
# 1                   Fakülte/Yüksekokul Adı  \
# ...

# %%
yks2 = pd.read_excel(r"C:\Users\utku-\Desktop\KAGGLE\BTK Hackaton\tablo3yd_22082023.xlsx")

# %%
yks2.columns = yks2.iloc[1]

# %%
yks2 = yks2.drop(index=[0,1])

# %%
yks2
# Out:
# 1     Program Kodu Üniversites Türü  \
# 2        200150352            VAKIF
# 3        200150361            VAKIF
# 4        200190088            VAKIF
# 5        200190081            VAKIF
# 6        200150767            VAKIF
# ...            ...              ...
# 9999     110390159           DEVLET
# 10000    110350761           DEVLET
# 10001    110351177           DEVLET
# 10002    110371093           DEVLET
# 10003    110350337           DEVLET
#
# 1                                         Üniversite Adı  \
# 2      ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 3      ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 4      ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 5      ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# 6      ACIBADEM MEHMET ALİ AYDINLAR ÜNİVERSİTESİ (İST...
# ...                                                  ...
# 9999                ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 10000               ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# ...

# %%
Yks_excel = pd.concat([yks,yks2], ignore_index=True)

# %%
Yks_excel.columns
# Out:
# Index(['Program Kodu', 'Üniversites Türü', 'Üniversite Adı',
#        'Fakülte/Yüksekokul Adı', 'Program Adı', 'Puan Türü', 'Kontenjan',
#        'Yerleşen', 'En Küçük Puan', 'En Büyük Puan', 'Kontenjan', 'Yerleşen',
#        'En Küçük Puan', 'En Büyük Puan', 'Kontenjan', 'Yerleşen',
#        'En Küçük Puan', 'En Büyük Puan', 'Kontenjan', 'Yerleşen',
#        'En Küçük Puan', 'En Büyük Puan', 'Kontenjan', 'Yerleşen',
#        'En Küçük Puan', 'En Büyük Puan'],
#       dtype='object', name=1)

# %%
Yks_excel
# Out:
# 1     Program Kodu Üniversites Türü                        Üniversite Adı  \
# 0        106510090           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 1        106510089           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 2        106510014           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 3        106510077           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 4        106510068           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# ...            ...              ...                                   ...
# 21860    110390159           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21861    110350761           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21862    110351177           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21863    110371093           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21864    110350337           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
#
# 1                   Fakülte/Yüksekokul Adı  \
# ...

# %%
new_column_names = [
    'Program Kodu', 'Üniversites Türü', 'Üniversite Adı',
    'Fakülte/Yüksekokul Adı', 'Program Adı', 'Puan Türü', 'Kontenjan',
    'Yerleşen', 'En Küçük Puan', 'En Büyük Puan', 'Kontenjan.1',
    'Yerleşen.1', 'En Küçük Puan.1', 'En Büyük Puan.1', 'Kontenjan.2',
    'Yerleşen.2', 'En Küçük Puan.2', 'En Büyük Puan.2', 'Kontenjan.3',
    'Yerleşen.3', 'En Küçük Puan.3', 'En Büyük Puan.3', 'Kontenjan.4',
    'Yerleşen.4', 'En Küçük Puan.4', 'En Büyük Puan.4'
]

# %%
Yks_excel.columns = new_column_names

# %%
Yks_excel.to_excel('yks_excel.xlsx', index=False)

# %%
yksexcel = pd.read_excel(r"C:\Users\utku-\Desktop\KAGGLE\BTK Hackaton\yks_excel.xlsx")

# %%
yksexcel
# Out:
#        Program Kodu Üniversites Türü                        Üniversite Adı  \
# 0         106510090           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 1         106510089           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 2         106510014           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 3         106510077           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# 4         106510068           DEVLET   ABDULLAH GÜL ÜNİVERSİTESİ (KAYSERİ)
# ...             ...              ...                                   ...
# 21860     110390159           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21861     110350761           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21862     110351177           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21863     110371093           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
# 21864     110350337           DEVLET  ZONGULDAK BÜLENT ECEVİT ÜNİVERSİTESİ
#
#                     Fakülte/Yüksekokul Adı  \
# ...

# %%
a= "Hoşgeldin" 
b= "ali"

# %%
print(a,b)
# Out:
# Hoşgeldin ali

# %%
len("Programlama")
# Out:
# 11
